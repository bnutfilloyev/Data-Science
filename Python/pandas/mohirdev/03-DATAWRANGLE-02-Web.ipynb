# %% [markdown]
# ![Imgur](https://i.imgur.com/5pXzCIu.png)
#
# # Data Science va Sun'iy Intellekt Praktikum
#
# ## 3-MODUL. MA’LUMOTLARGA ISHLOV BERISH
#
# ### 3.1 Fayllar bilan ishlash

# %% [markdown]
# ### Web fayllar bilan ishlash
# #### `read_html()` - web sahifadagi barcha jadvallarni o'qib, `DataFrame1lardan iborat ro'yxat ko'rinishida qaytaradi.

# %%
import pandas as pd

# %%
data = pd.read_html("https://en.wikipedia.org/wiki/Tashkent")

# %% [markdown]
# `data` tarkibida sahifadagi barcha jadvallar alohida `DataFrame` ko'rinishida saqlangan. Jadvallar sonini ko'rish uchun `len()` funksiyasiga murojaat qilamiz.

# %%
len(data)
# Out:
# 16

# %% [markdown]
# Yuqoridagi data tarkibida 16 ta DataFrame bor ekan. Alohida DataFramelarga indeks orqali murojaat qilishimiz mumkin.
# Ba'zida kerakli jadvlani topguncha bir necha indekslarni qarab chiqish talab qilinishi mumkin.

# %%
data[5]
# Out:
#    Climate data for Tashkent (1981–2010, extremes 1881–present)  \
#                                                           Month
# 0                                 Record high °C (°F)
# 1                                Average high °C (°F)
# 2                                  Daily mean °C (°F)
# 3                                 Average low °C (°F)
# 4                                  Record low °C (°F)
# 5                   Average precipitation mm (inches)
# 6                          Average precipitation days
# 7                                  Average snowy days
# 8                       Average relative humidity (%)
# 9                         Mean monthly sunshine hours
# 10  Source 1: Centre of Hydrometeorological Servic...
# 11  Source 2: Pogoda.ru.net (mean temperatures/hum...
#
#                                                        \
#                                                   Jan
# 0                                          22.6(72.7)
# 1                                           6.9(44.4)
# 2                                           1.9(35.4)
# 3                                          −1.5(29.3)
# 4                                            −28(−18)
# 5                                          53.3(2.10)
# 6                                                  14
# 7                                                   9
# 8                                                  73
# 9                                               117.3
# 10  Source 1: Centre of Hydrometeorological Servic...
# 11  Source 2: Pogoda.ru.net (mean temperatures/hum...
#
#                                                        \
#                                                   Feb
# 0                                          27.0(80.6)
# 1                                           9.4(48.9)
# 2                                           3.9(39.0)
# 3                                           0.0(32.0)
# 4                                        −25.6(−14.1)
# 5                                          63.8(2.51)
# 6                                                  13
# 7                                                   7
# 8                                                  68
# 9                                               125.3
# 10  Source 1: Centre of Hydrometeorological Servic...
# 11  Source 2: Pogoda.ru.net (mean temperatures/hum...
#
#                                                        \
#                                                   Mar
# 0                                          32.5(90.5)
# 1                                          15.2(59.4)
# 2                                           9.3(48.7)
# 3                                           4.8(40.6)
# 4                                          −16.9(1.6)
# 5                                          70.2(2.76)
# 6                                                  14
# 7                                                   2
# 8                                                  61
# 9                                               165.1
# 10  Source 1: Centre of Hydrometeorological Servic...
# 11  Source 2: Pogoda.ru.net (mean temperatures/hum...
#
#                                                        \
#                                                   Apr
# 0                                          36.4(97.5)
# 1                                          22.0(71.6)
# 2                                          15.5(59.9)
# 3                                           9.8(49.6)
# 4                                          −6.3(20.7)
# 5                                          62.3(2.45)
# 6                                                  12
# 7                                                   0
# 8                                                  60
# 9                                               216.8
# 10  Source 1: Centre of Hydrometeorological Servic...
# 11  Source 2: Pogoda.ru.net (mean temperatures/hum...
#
#                                                        \
#                                                   May
# 0                                         39.9(103.8)
# 1                                          27.5(81.5)
# 2                                          20.5(68.9)
# 3                                          13.7(56.7)
# 4                                          −1.7(28.9)
# 5                                          41.2(1.62)
# 6                                                  11
# 7                                                   0
# 8                                                  53
# 9                                               303.4
# 10  Source 1: Centre of Hydrometeorological Servic...
# 11  Source 2: Pogoda.ru.net (mean temperatures/hum...
#
#                                                        \
#                                                   Jun
# 0                                         43.0(109.4)
# 1                                          33.4(92.1)
# 2                                          25.8(78.4)
# 3                                          18.1(64.6)
# 4                                           3.8(38.8)
# 5                                          14.3(0.56)
# 6                                                   7
# 7                                                   0
# 8                                                  40
# 9                                               361.8
# 10  Source 1: Centre of Hydrometeorological Servic...
# 11  Source 2: Pogoda.ru.net (mean temperatures/hum...
#
#                                                        \
#                                                   Jul
# 0                                         44.6(112.3)
# 1                                          35.6(96.1)
# 2                                          27.8(82.0)
# 3                                          19.7(67.5)
# 4                                           8.2(46.8)
# 5                                           4.5(0.18)
# 6                                                   4
# 7                                                   0
# 8                                                  39
# 9                                               383.7
# 10  Source 1: Centre of Hydrometeorological Servic...
# 11  Source 2: Pogoda.ru.net (mean temperatures/hum...
#
#                                                        \
#                                                   Aug
# 0                                         43.1(109.6)
# 1                                          34.7(94.5)
# 2                                          26.2(79.2)
# 3                                          18.1(64.6)
# 4                                           5.7(42.3)
# 5                                           1.3(0.05)
# 6                                                   3
# 7                                                   0
# 8                                                  42
# 9                                               365.8
# 10  Source 1: Centre of Hydrometeorological Servic...
# 11  Source 2: Pogoda.ru.net (mean temperatures/hum...
#
#                                                        \
#                                                   Sep
# 0                                         40.0(104.0)
# 1                                          29.3(84.7)
# 2                                          20.6(69.1)
# 3                                          13.0(55.4)
# 4                                           0.1(32.2)
# 5                                           6.0(0.24)
# 6                                                   3
# 7                                                   0
# 8                                                  45
# 9                                               300.9
# 10  Source 1: Centre of Hydrometeorological Servic...
# 11  Source 2: Pogoda.ru.net (mean temperatures/hum...
#
#                                                        \
#                                                   Oct
# 0                                          37.5(99.5)
# 1                                          21.8(71.2)
# 2                                          13.9(57.0)
# 3                                           7.8(46.0)
# 4                                         −11.2(11.8)
# 5                                          24.7(0.97)
# 6                                                   7
# 7                                                   1
# 8                                                  57
# 9                                               224.8
# 10  Source 1: Centre of Hydrometeorological Servic...
# 11  Source 2: Pogoda.ru.net (mean temperatures/hum...
#
#                                                        \
#                                                   Nov
# 0                                          31.6(88.9)
# 1                                          14.9(58.8)
# 2                                           8.5(47.3)
# 3                                           4.1(39.4)
# 4                                         −22.1(−7.8)
# 5                                          43.9(1.73)
# 6                                                  10
# 7                                                   2
# 8                                                  66
# 9                                               149.5
# 10  Source 1: Centre of Hydrometeorological Servic...
# 11  Source 2: Pogoda.ru.net (mean temperatures/hum...
#
#                                                        \
#                                                   Dec
# 0                                          27.3(81.1)
# 1                                           8.8(47.8)
# 2                                           3.5(38.3)
# 3                                           0.0(32.0)
# 4                                        −29.5(−21.1)
# 5                                          58.9(2.32)
# 6                                                  12
# 7                                                   6
# 8                                                  73
# 9                                               105.9
# 10  Source 1: Centre of Hydrometeorological Servic...
# 11  Source 2: Pogoda.ru.net (mean temperatures/hum...
#
#
#                                                  Year
# 0                                         44.6(112.3)
# 1                                          21.6(70.9)
# 2                                          14.8(58.6)
# 3                                           9.0(48.2)
# 4                                        −29.5(−21.1)
# 5                                        444.4(17.50)
# 6                                                 110
# 7                                                  27
# 8                                                  56
# 9                                              2820.3
# 10  Source 1: Centre of Hydrometeorological Servic...
# 11  Source 2: Pogoda.ru.net (mean temperatures/hum...

# %%
data[7]
# Out:
#     Nr       District  Population (2009)[60]  Area (km2)[60]  \
# 0    1       Bektemir                  27500            20.5
# 1    2      Chilanzar                 217000            30.0
# 2    3      Yashnobod                 204800            33.7
# 3    4        Mirobod                 122700            17.1
# 4    5  Mirzo Ulugbek                 245200            31.9
# 5    6        Sergeli                 149000            56.0
# 6    7  Shaykhontohur                 285800            27.2
# 7    8        Olmazar                 305400            34.5
# 8    9        Uchtepa                 237000            28.2
# 9   10     Yakkasaray                 115200            14.6
# 10  11      Yunusabad                 296700            41.1
#
#     Density (area/km2)[60]  Map
# 0                     1341  NaN
# 1                     7233  NaN
# 2                     6077  NaN
# 3                     7175  NaN
# 4                     7687  NaN
# 5                     2661  NaN
# 6                    10507  NaN
# 7                     8852  NaN
# 8                     8404  NaN
# 9                     7890  NaN
# 10                    7219  NaN

# %% [markdown]
# ### JSON format

# %% [markdown]
# JSON web orqali ma'lumotlarni uzatishda ishlatiluvchi eng mashhur formatlardan. JSON haqida Dasturlash Asoslari darsimizda batafsil ma'lumot berilgan: https://python.sariq.dev/files-exceptions/34-json

# %%
pd.read_json("universities_ranking.json")
# Out:
#       ranking                                           title        location  \
# 0           1                            University of Oxford  United Kingdom
# 1           2                             Stanford University   United States
# 2           3                              Harvard University   United States
# 3           4              California Institute of Technology   United States
# 4           5           Massachusetts Institute of Technology   United States
# ...       ...                                             ...             ...
# 1521     1522                              Yuan Ze University          Taiwan
# 1522     1523  Yuriy Fedkovych Chernivtsi National University         Ukraine
# 1523     1524                              Zagazig University           Egypt
# 1524     1525                            University of Zagreb         Croatia
# 1525     1526                            University of Žilina        Slovakia
#
#      number students  students staff ratio perc intl students gender ratio
# 0             20,774                  11.1                41%      46 : 54
# 1             16,223                   7.4                23%      44 : 56
# 2             21,261                   9.3                25%      49 : 51
# 3              2,238                   6.3                33%      36 : 64
# 4             11,276                   8.4                34%      39 : 61
# ...              ...                   ...                ...          ...
# 1521           8,188                  19.7                 7%      42 : 58
# 1522          12,616                  10.7                 0%      57 : 43
# 1523         156,270                  24.4                 2%      54 : 46
# 1524          59,336                  15.3                 3%      59 : 41
# 1525           7,136                  11.7                 2%      34 : 66
#
# [1526 rows x 7 columns]

# %%
import requests, json
r = requests.get('http://api.nobelprize.org/v1/laureate.json')
data = r.json()
# data['laureates']
pd.DataFrame(data['laureates'],)
# Out:
#        id       firstname    surname        born        died  \
# 0       1  Wilhelm Conrad    Röntgen  1845-03-27  1923-02-10
# 1       2      Hendrik A.    Lorentz  1853-07-18  1928-02-04
# 2       3          Pieter     Zeeman  1865-05-25  1943-10-09
# 3       4           Henri  Becquerel  1852-12-15  1908-08-25
# 4       5          Pierre      Curie  1859-05-15  1906-04-19
# ..    ...             ...        ...         ...         ...
# 963  1005           Maria      Ressa  1963-10-02  0000-00-00
# 964  1006          Dmitry    Muratov  1961-00-00  0000-00-00
# 965  1007           David       Card  1956-00-00  0000-00-00
# 966  1008          Joshua    Angrist  1960-00-00  0000-00-00
# 967  1009           Guido     Imbens  1963-09-03  0000-00-00
#
#                bornCountry bornCountryCode                bornCity  \
# 0    Prussia (now Germany)              DE  Lennep (now Remscheid)
# 1          the Netherlands              NL                  Arnhem
# 2          the Netherlands              NL              Zonnemaire
# 3                   France              FR                   Paris
# 4                   France              FR                   Paris
# ..                     ...             ...                     ...
# 963            Philippines              PH                  Manila
# 964      USSR (now Russia)              RU   Kubyshev (now Samara)
# 965                 Canada              CA                  Guelph
# 966                    USA              US            Columbus, OH
# 967        the Netherlands              NL                     NaN
#
#          diedCountry diedCountryCode   diedCity  gender  \
# 0            Germany              DE     Munich    male
# 1    the Netherlands              NL        NaN    male
# 2    the Netherlands              NL  Amsterdam    male
# 3             France              FR        NaN    male
# 4             France              FR      Paris    male
# ..               ...             ...        ...     ...
# 963              NaN             NaN        NaN  female
# 964              NaN             NaN        NaN    male
# 965              NaN             NaN        NaN    male
# 966              NaN             NaN        NaN    male
# 967              NaN             NaN        NaN    male
#
#                                                 prizes
# 0    [{'year': '1901', 'category': 'physics', 'shar...
# 1    [{'year': '1902', 'category': 'physics', 'shar...
# 2    [{'year': '1902', 'category': 'physics', 'shar...
# 3    [{'year': '1903', 'category': 'physics', 'shar...
# 4    [{'year': '1903', 'category': 'physics', 'shar...
# ..                                                 ...
# 963  [{'year': '2021', 'category': 'peace', 'share'...
# 964  [{'year': '2021', 'category': 'peace', 'share'...
# 965  [{'year': '2021', 'category': 'economics', 'sh...
# 966  [{'year': '2021', 'category': 'economics', 'sh...
# 967  [{'year': '2021', 'category': 'economics', 'sh...
#
# [968 rows x 13 columns]

# %% [markdown]
# ### Web API
# API haqida tushuncha hosil qilish uchun quyidagi 2 videoni ko'rishni tavsiya qilaman:
# - https://youtu.be/eID-mIzjb-E
# - https://youtu.be/QoKcBFLd2aE

# %%
r = requests.get("https://openlibrary.org/subjects/python.json?published_in=2015-2021")
pd.DataFrame(r.json()['works'])
# Out:
#                    key                                              title  \
# 0   /works/OL17389190W                              Flask Web Development
# 1   /works/OL24148259W                              Python dla wszystkich
# 2   /works/OL17854515W  Aprendiendo a programar en Python con mi compu...
# 3   /works/OL17842208W                         Python Guide Documentation
# 4   /works/OL17930014W                                  Learn Programming
# 5   /works/OL20659898W                                       Data Science
# 6   /works/OL19543337W  Python Programming: An Introduction to Compute...
# 7   /works/OL19086047W  Ядро геометричного моделювання Open CASCADE Te...
# 8   /works/OL19087942W  Мова програмування Python для інженерів і наук...
# 9   /works/OL20115118W  Pygame - Initiez-vous au développement de jeux...
# 10  /works/OL20094082W                                      Python Basics
# 11  /works/OL20771642W          Getting Started with Python Data Analysis
#
#     edition_count  cover_id cover_edition_key  \
# 0               2   7481270       OL25969321M
# 1               1  10546711       OL31864729M
# 2               1   8155686       OL26439085M
# 3               1   8138241       OL26428659M
# 4               1   8259792       OL26502131M
# 5               1   9322714       OL27934739M
# 6               1   8509622       OL26834029M
# 7               1   8401758       OL26752469M
# 8               1   8404333       OL26754906M
# 9               1   8773342       OL27295084M
# 10              1   8758915       OL27274131M
# 11              1  10331432       OL28110675M
#
#                                               subject  \
# 0   [Software frameworks, Web applications, Applic...
# 1                [python, programming, programowanie]
# 2   [Computing, Technology, Software, Programming ...
# 3   [Python, Python 3, Programming languages, Comp...
# 4   [Software development, Programming languages, ...
# 5   [Probability, Mathematics, Statistics, Data Sc...
# 6        [Python, Python (Computer program language)]
# 7   [Open CASCADE Technology, Python, geometric mo...
# 8   [Python, programming, programming language, tu...
# 9           [Pygame, Python, video games, jeux video]
# 10  [Python, Programming, Financial markets, algor...
# 11                            [python, data analysis]
#
#                                         ia_collection  lendinglibrary  \
# 0                                                  []           False
# 1                                                  []           False
# 2           [opensource, community, fav-scarlettdidi]           False
# 3                             [community, opensource]           False
# 4   [fav-h_seyin_uzun, fav-steveniic, community, f...           False
# 5                                                  []           False
# 6                                                  []           False
# 7                             [community, opensource]           False
# 8                             [community, opensource]           False
# 9                                                  []           False
# 10  [fav-rkrajhan, fav-georgeknight, fav-linhvu91,...           False
# 11                                                 []           False
#
#     printdisabled lending_edition lending_identifier  \
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# 5           False
# 6           False
# 7           False
# 8           False
# 9           False
# 10          False
# 11          False
#
#                                               authors first_publish_year  \
# 0   [{'key': '/authors/OL626174A', 'name': 'Miguel...               None
# 1   [{'key': '/authors/OL6751191A', 'name': 'Charl...               None
# 2   [{'key': '/authors/OL7410826A', 'name': 'Sergi...               None
# 3   [{'key': '/authors/OL7408931A', 'name': 'Kenne...               None
# 4   [{'key': '/authors/OL7423013A', 'name': 'Antti...               None
# 5   [{'key': '/authors/OL7828687A', 'name': 'Chant...               None
# 6   [{'key': '/authors/OL7495807A', 'name': 'John ...               None
# 7   [{'key': '/authors/OL7468440A', 'name': 'Volod...               None
# 8   [{'key': '/authors/OL7468440A', 'name': 'Volod...               None
# 9   [{'key': '/authors/OL7447082A', 'name': 'Benoî...               None
# 10                                                 []               None
# 11  [{'key': '/authors/OL7915587A', 'name': 'Phuon...               None
#
#                                                    ia  public_scan  \
# 0                                                None        False
# 1                                                None        False
# 2    2016AprendiendoAProgramarEnPythonConMiComputador         True
# 3                        2018PythonGuideDocumentation         True
# 4                                2018LearnProgramming         True
# 5                                                None        False
# 6                                                None        False
# 7                               OpenCASCADETechnology         True
# 8                                          Python2019         True
# 9                                                None        False
# 10  pythonbasicswithillustrationsfromthefinancialm...         True
# 11                                               None        False
#
#     has_fulltext                                       availability
# 0          False                                                NaN
# 1          False                                                NaN
# 2           True  {'status': 'open', 'available_to_browse': Fals...
# 3           True  {'status': 'open', 'available_to_browse': Fals...
# 4           True  {'status': 'open', 'available_to_browse': Fals...
# 5          False                                                NaN
# 6          False                                                NaN
# 7           True  {'status': 'private', 'available_to_browse': F...
# 8           True  {'status': 'private', 'available_to_browse': F...
# 9          False                                                NaN
# 10          True  {'status': 'private', 'available_to_browse': F...
# 11         False                                                NaN
